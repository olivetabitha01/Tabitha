# %% [markdown]
# <a href="https://colab.research.google.com/github/olivetabitha01/Tabitha/blob/main/QuantaH2O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML MODEL DAM

# %% [markdown]
# #**Load data**

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f59ec10-2d3f-4613-bfe2-9e650a2a6506" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f59ec10-2d3f-4613-bfe2-9e650a2a6506">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df = pd.read_excel(io.BytesIO(uploaded['tancam24 4 (1).xlsx']))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-afd02906026d> in <cell line: 1>()
# ----> 1 df = pd.read_excel(io.BytesIO(uploaded['tancam24 4 (1).xlsx']))
#       2 df
#       3 df.values.tolist()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Data seperation as x and y

# %%
y = df['Outflow (m^3/s)']
y
# Out:
# 0     20.0
# 1     25.0
# 2     30.0
# 3     35.0
# 4     40.0
# 5     40.0
# 6     45.0
# 7     50.0
# 8     55.0
# 9     60.0
# 10    50.0
# 11    45.0
# 12    40.0
# 13    35.0
# 14    30.0
# 15    25.0
# 16    20.0
# 17    15.0
# 18    10.0
# 19     5.0
# 20     5.0
# 21    10.0
# 22     5.0
# 23    20.0
# 24    25.0
# 25    30.0
# 26    35.0
# 27    40.0
# 28    45.0
# 29    50.0
# 30    55.0
# 31    50.0
# 32    45.0
# 33    40.0
# 34    35.0
# 35    30.0
# 36    25.0
# 37    20.0
# 38    15.0
# 39    10.0
# 40     5.0
# 41     5.0
# 42     5.0
# 43     5.0
# 44    10.0
# 45    15.0
# 46    20.0
# 47    25.0
# 48     NaN
# Name: Outflow (m^3/s), dtype: float64

# %%
x = df.drop('Outflow (m^3/s)', axis=1)
x
# Out:
#     Dam Name  month.year  Height in m  Length in m  Crest Width in m  \
# 0          1        1.20         25.0       4500.0              10.0
# 1          1        2.20         25.0       4500.0              10.0
# 2          1        3.20         25.0       4500.0              10.0
# 3          1        4.20         25.0       4500.0              10.0
# 4          1        5.20         25.0       4500.0              10.0
# 5          1        6.20         25.0       4500.0              10.0
# 6          1        7.20         25.0       4500.0              10.0
# 7          1        8.20         25.0       4500.0              10.0
# 8          1        9.20         25.0       4500.0              10.0
# 9          1       10.20         25.0       4500.0              10.0
# 10         1       11.20         24.0       4500.0              10.0
# 11         1       12.20         24.0       4500.0              10.0
# 12         1        1.21         24.0       4500.0              10.0
# ...

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
x_train
# Out:
#     Dam Name  month.year  Height in m  Length in m  Crest Width in m  \
# 0          1        1.20         25.0       4500.0              10.0
# 11         1       12.20         24.0       4500.0              10.0
# 37         1        2.23         22.5       4500.0              10.0
# 18         1        7.21         24.0       4500.0              10.0
# 35         1       12.22         22.5       4500.0              10.0
# 25         1        2.22         23.0       4500.0              10.0
# 36         1        1.23         22.5       4500.0              10.0
# 17         1        6.21         24.0       4500.0              10.0
# 7          1        8.20         25.0       4500.0              10.0
# 46         1       11.23         21.0       4500.0              10.0
# 44         1        9.23         22.5       4500.0              10.0
# 26         1        3.22         23.0       4500.0              10.0
# 19         1        8.21         24.0       4500.0              10.0
# ...

# %%
x_test
# Out:
#     Dam Name  month.year  Height in m  Length in m  Crest Width in m  \
# 6          1        7.20         25.0       4500.0              10.0
# 20         1        9.21         24.0       4500.0              10.0
# 33         1       10.22         22.5       4500.0              10.0
# 28         1        5.22         23.0       4500.0              10.0
# 42         1        7.23         22.5       4500.0              10.0
# 48         1         NaN          NaN          NaN               NaN
# 5          1        6.20         25.0       4500.0              10.0
# 32         1        9.22         22.5       4500.0              10.0
# 41         1        6.23         22.5       4500.0              10.0
# 31         1        8.22         22.5       4500.0              10.0
#
#     Base Width in m  Construction Started  Construction Completed  \
# 6             200.0                1934.0                  1939.0
# 20            200.0                1934.0                  1939.0
# ...

# %% [markdown]
# # Model Building

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ### Training the model

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
print(y_train.head())
# Out:
# 0     20.0
# 11    45.0
# 37    20.0
# 18    10.0
# 35    30.0
# Name: Outflow (m^3/s), dtype: float64

# %%
y_train = pd.to_numeric(y_train, errors='coerce')

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Appling the model to make predictions**

# %%
print(x_train.isnull().sum())
print(x_test.isnull().sum())
# Out:
# Dam Name                                                   0
# month.year                                                 0
# Height in m                                                0
# Length in m                                                0
# Crest Width in m                                           0
# Base Width in m                                            0
# Construction Started                                       0
# Construction Completed                                     0
# Reservoir Capacity in million cubic feet (MCft)            0
# Surface Area in square kilometers                          0
#  Maximum Water Discharge in cubic feet per second (cfs)    0
# Water level (m)                                            0
# Inflow (m^3/s)                                             0
# Rainfall (mm)                                              0
# Sedimentation (kg/m^2)                                     0
# ...

# %%
cols_with_missing_values = x_train.columns[x_train.isnull().any()]

# %%
# Option 1: Drop rows with missing values
x_train = x_train.dropna()
x_test = x_test.dropna()

# Option 2: Impute missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_lr_train_pred
# Out:
# array([-2.83668969,  0.84208401, -0.50930302, -0.13058053, -1.6269208 ,
#        -2.86103037, -2.32208333, -4.16684323, -5.04235077, -2.29737009,
#        -3.15082845, -4.33037208, -1.43700682, -2.59060064, -7.09025955,
#        -2.32734557, -4.19073421, -2.63904005, -3.58104074, -3.75929058,
#        -2.5501665 , -3.26968347, -2.78911367, -2.69251051, -0.77437547,
#        -6.61955792, -2.99084623, -2.36975061, -7.18167736, -1.52816491,
#        -4.81736265, -0.86996608, -7.09025955, -1.87404275, -2.58013247,
#        -4.80953284, -4.17454084, -1.95444152, -3.50503339, -2.7411418 ,
#        -1.87131835, -2.45270806, -3.07252433, -1.48988982, -3.98778754,
#        -1.35216679, -0.16932277, -6.05237002, -3.29550658,  0.30513174,
#        -3.25501463, -5.31993586, -0.4733928 , -4.79180882, -5.82486323,
#        -2.70343539, -3.70838271, -2.4987341 , -2.12301018, -3.11393974,
#        -2.79842053, -1.38274662, -4.3267103 , -3.57778946, -3.42356884,
# ...

# %%
y_lr_test_pred
# Out:
# array([44.91911094,  3.98446759, 44.4011398 , 48.19151238,  1.72919353,
#        38.49737861, 39.04746475,  1.49592409, 45.60249394])

# %% [markdown]
# ### **Evaluate model performance**

# %%
print(f"Length of y_test: {len(y_test)}")
print(f"Length of y_lr_test_pred: {len(y_lr_test_pred)}")
# Out:
# Length of y_test: 10
# Length of y_lr_test_pred: 9

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

y_lr_test_pred_padded = imputer.fit_transform(y_lr_test_pred.reshape(-1, 1))

# %%
y_test_truncated = y_test[:len(y_lr_test_pred)]

# %%
print(len(y_test))
print(len(y_lr_test_pred))
# Out:
# 10
# 9

# %%
y_lr_test_pred = np.pad(y_lr_test_pred, (0, len(y_test) - len(y_lr_test_pred)))

# %%
# Import the NumPy module
import numpy as np

# Print the shapes of y_test and y_lr_test_pred
print(y_test.shape)
print(y_lr_test_pred.shape)

# Print the data types of y_test and y_lr_test_pred
print(y_test.dtype)
print(y_lr_test_pred.dtype)

# Check for missing values in y_test and y_lr_test_pred
print(np.isnan(y_test).sum())
print(np.isnan(y_lr_test_pred).sum())
# Out:
# (10,)
# (10,)
# float64
# float64
# 1
# 0

# %%
print(y_test)
print(y_lr_test_pred)
# Out:
# 6     45.0
# 20     5.0
# 33    40.0
# 28    45.0
# 42     5.0
# 48     NaN
# 5     40.0
# 32    45.0
# 41     5.0
# 31    50.0
# Name: Outflow (m^3/s), dtype: float64
# [44.91911094  3.98446759 44.4011398  48.19151238  1.72919353 38.49737861
#  39.04746475  1.49592409 45.60249394  0.        ]

# %%
import pandas as pd

df_test = pd.DataFrame({"y_test": y_test, "y_pred": y_lr_test_pred})
df_test.isnull().sum()
# Out:
# y_test    1
# y_pred    0
# dtype: int64

# %%
df_test.dropna(inplace=True)
y_test = df_test["y_test"]
y_lr_test_pred = df_test["y_pred"]

# %%
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train):',lr_train_mse)
print('LR R2 (Train):',lr_train_r2)
print('LR MSE (Test):',lr_test_mse)
print('LR R2 (Train):',lr_test_r2)
# Out:
# LR MSE (Train): 3.861051652988577
# LR R2 (Train): 0.9835315211323734
# LR MSE (Test): 675.92958494441
# LR R2 (Train): -0.9380635886901663

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method','Training MSE','Training R2','Test MSE','Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear regression     3.861052    0.983532  675.929585 -0.938064

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Training the Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### Evaluate Model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method','Training MSE','Training R2','Test MSE','Test R2']
rf_results
# Out:
#           Method Training MSE Training R2 Test MSE   Test R2
# 0  Random Forest    10.503352      0.9552   7.1171  0.979593

# %% [markdown]
# ## **Model comparision**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear regression     3.861052    0.983532  675.929585 -0.938064
# 0      Random Forest    10.503352      0.9552      7.1171  0.979593

# %%
df_models.reset_index(drop = True)
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear regression     3.861052    0.983532  675.929585 -0.938064
# 1      Random Forest    10.503352      0.9552      7.1171  0.979593

# %% [markdown]
# # **Data Visualization of predicted result**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred,c='#7CAE00', alpha=0.5)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train),'#F8766D')
plt.ylabel('predict Outflow (m^3/s)')
plt.xlabel('Experimental Outflow (m^3/s)')
# Out:
# Text(0.5, 0, 'Experimental Outflow (m^3/s)')

# %% [markdown]
# ### New Section
